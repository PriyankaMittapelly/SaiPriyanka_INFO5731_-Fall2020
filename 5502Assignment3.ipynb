# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankaMittapelly/SaiPriyanka_INFO5731_-Fall2020/blob/main/5502Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries

import numpy as np
import matplotlib.pyplot as plt

# %%
records=[10,500,1000,5000,10000,50000,80000,100000,200000]

list_pi=[]

for lis in records:
    
#generate list of random number for both x, y coordinates
  x=np.random.uniform(0,1,[lis,1])
  y=np.random.uniform(0,1,[lis,1])

  #check to see if point is inside or outside circle
  inside_circle = ((x-0.5)**2+(y-0.5)**2) <0.25


  # calaculate pi value
  pi=4*np.sum(inside_circle)/lis
  list_pi.append(pi)


  #filter for list of points inside the circle
  x_in=x[inside_circle]
  y_in=y[inside_circle]

#ploting the graph

  fig=plt.figure()
  plt.scatter(x, y, c='b', s=1)
  plt.scatter(x_in, y_in, color='r',s=1)
  circle1 = plt.Circle((0.5,0.5), 0.5, color='black',fill=False)
  plt.gcf().gca().add_artist(circle1)
  plt.show()
  print("value of pi for "+str(lis)+" records is"+str(pi))
# Out:
# value of pi for 10 records is3.2
# value of pi for 500 records is3.192
# value of pi for 1000 records is3.152
# value of pi for 5000 records is3.1656
# value of pi for 10000 records is3.1276
# value of pi for 50000 records is3.13544
# value of pi for 80000 records is3.1401
# value of pi for 100000 records is3.13868
# value of pi for 200000 records is3.14062

# %%
fig=plt.figure()
plt.plot(num_of_rec,list_pi)
plt.show()
