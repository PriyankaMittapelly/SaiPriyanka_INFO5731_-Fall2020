# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankaMittapelly/SaiPriyanka_INFO5731_-Fall2020/blob/main/5501_ass1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
DESCRIPTION ON HOW THE SORTING OF STRING WORKS FOR THE BELOW CODE  


No sorting technique is used and a method is defined to pass all the five test cases string. For loop is used to get the index value 
and inner loops are used to retrive the first and second letter of the string to perform the comparison of the strings , and sort them using swap method. 
using join function , merging the strings togther and storing them in S variable using append function .

Using matplotlib package ,  visualization of  scatter plot is made with x - axis as the length of the string and y dimension as the order of the string .

# %%
def test_case(a):
  s=[]
  for i in range(0,len(a)): #indexing the str
    t=list(a[i])
    #print(type(p))


    for k in range(0,len(t)):  #indexing the first letter
      #print(t[k])

      for j in range(k+1,len(t)): # Indexing for the second letter
        #print(t[j])

        if t[k]>t[j]:
          t[k],t[j]=t[j],t[k]  # sorting the string using swap method
          combine="".join(t)
    s.append(combine)
    p=[]
    m=[]
    for i in range(0,len(a)):
      p.append(i)
      m.append(len(a[i]))
 
import matplotlib.pyplot as plt
plt.xlabel("Length of the string")
plt.ylabel("Order of the string")
plt.title("visualizing all  string based on length")
plt.scatter(p,m)

# %%
test_case(["are45","jhgdsj^%$@","GHJ546$%^","ram6$","varun","teja7","venkat","saiteja576","sunil%^^","Vamsi*^9","deekshith#2",
"srikanth%^","Saikumar%$@","gfhfhfjfghfhgcgfdfghd","iamgoing34","tomovie","whatis","shedoing@","itoldher12","bealright",
"cdechu2","Elsewr2","rain123","1icebc","ekuva4","!h!nn","chiru","vamsi56","$%gvfh","zzzzzz","money%$5","%&^%gh","&^8chjira",
"11fhgd","635fgjh","ghjhd","^56gfh","gdhs67^%",'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua', 'Barbuda',
'Argentina', 'Armenia', 'Australia', 'Austria', 'Austrian', 'Empire', 'Azerbaijan', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Maligh', 
'Malta', 'Marshall', 'Islands', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique'
"kjfjkjs","%$65gjhg","hdjagja","hfhjs","^7ygtd","%76ghsd","gsjgfjeggsdjhf","bcjhgcg","djahdjuy674","bfjhwg76","hgfjs","ewgu"
"jkfhgsf","bjaugd56","^%&ghhdg","hfgbsujg","*&^&hndskj","^*&*&^","!#@#$#$%","$#%%^*&^","&**^&%","GVF%^87","HJGGJHGJGHUYg","GFHHgfyt76",'Panama', 'Argeghjntina', 'Barbados',
'Belarus', 'Philghippines', 'Nassau*', 'Bahrain', 'Bangladesh', 'Belgium', 'Austria', 'Guinea', 'Paraguay', 'Bahamas,', 'Bavaria*', 'Austrian', 'Nicaragua', 'Nigeria', 'Barbuda',
'Azerbaijan', 'States*', 'Piedmont-Sardin', 'Antigua', 'Albania', 'Andorra', 'Pakistan', 'Zealand', 'Algeria', 'Australia', 'Angola', 'Belize', 'Namibia', 'Empire', 'Netherlands,', 
'Armenia', 'Afghanistan','Swoosh', 'Furiosa', 'SpeedX', 'Firebrand', 'Burner', 'Orange', 'Brimstone', 'Apollo', 'Knockout', 'Hannibal', 'Clockwork', 'Imperator', 'Furious', 'Strangeglove',
'Screech', 'Furiosa', 'Scorch', 'Roadrunner', 'Clockwork', 'Torcher', 'Hoover', 'Divebomb','BloodDiamond', 'Slammer', 'Dumptruck', 'RedOctober', 'MerlotTNTDiablo', 'Taurus', 'PearlyTailgate',
'Monster', 'LightningMcQueen', 'TheDonald', 'FerrisBueller', 'IgniteRoad', 'Ladybug', 'Squeaker', 'SummerVacation', 'Wheezy', 'Roadkill', 'RedBull', 'Caroline', 'Sawdust', 'Craigslist', 'YosemiteSamStepchild',
'Gravedigger', 'Champion', 'Garbage', 'Bloody', 'Cherry', 'Michael', 'SwampThing', 'Doomsday', 'Sawbones', 'DieHardJunkyard', 'PavementFace', 'Troublemaker', 'Rosanne', 'Dynamite', 'RedHot', 'Arnold',
'HighwaytoHell', 'CrimsonMachine', 'Starsky', 'Jordan', 'Paycheck', 'Bloodshot', 'Vulture', 'Komoda', 'ToneZone', 'Basketcase', 'Sasquatch', 'Murder', 'TheGoon', 'RonBurgundy', 'Nightcrawler', 'Bloodsoaked',
'Bonecrusher', 'CliffordtheBig', 'Redbull', 'BlazingSaddles', 'Magnum', 'BobtheDestroyer',"6757687","778648","8765348","347%^^g"
"%$hggdh","UYTGtgdsgj","hgfjsyh","hfihsdfhsdfh","6gfh879","76ghdfjk","y657834","64hgjhfg","fhsj87^jdrhg","rhgfjuhdf",
"sjhgdfnbchj","djfnhgiudfhf","shgbfheg","*&^87jhbgcjvhg","qpplrfjirj","gvgh*(&5)","*&*76hjhdfg","hfjksdhfuh","*&^&6hgcjhgd",
"GFUYgdyfg","*^876hcjhdg","&*hjsgdhj","^&djkhf87","fngkjsdh","fhgeurytnbsdhf",'mht654', '12fonny', 'cassty', 'EFghgh', 'hel!@lo',
'carloan', 'EFgh!!', 'malayam', 'google', 'kolly1', 'ekuva4', 'golddy4', 'hellohek', 'babyzz', 'aeonny', 'aug456', 'cdechu2', 'broomh', 'foxxyc', 'gujarath', '!loveu', 'july24', '1ijk2c', 'country', 'pinny1', 'bronze',
'gonny67', 'summer23', 'farmy2', 'helloby7', 'tfstool1', 'silver3', 'qa34ed', 'itsolu!123', '!missu', 'abc123894', 'sweaty4', 'pickup', 'hatty12', 'pillow23', 'cookee', 'tracj2', 'ruangry1', 'ammulu', 'drescc', '!mkoph',
'c1v2b3', 'sprout', 'gmail2', '1icebc', 'shaivi@15', 'cdemjy', 'doxxy1', 'madboy', 'danger45', 'piece2', 'wtztht', 'carlone', 'enjoy78', 'nastory', 'vrushi!', 'simha12', 'abc123!', 'mouth67', 'good12', 'iconoic', 'aolly3',
'A123ss', 'cdecde', 'biscuit', 'pppu78', 'work12', 'fruit!3', '12345mnbv', 'ABlmnC', 'shaivi', 'E@wrebh', 'spinach', 'gold34', 'february', 'abc66444', 'win123', 'gutarat', 'hotmail1', 'pressy', 'friut2', '!!!!!$wecgh', 'm1n2b3',
'tollyu', 'bankloan', 'denton', 'eoxxy2', 'meaty2', 'bed456', 'ABC@!sd', 'abc123444', 'sweety', 'january', 'fall34', 'Ellenb56gh', 'hapy76', 'cunning', 'cdednt', 'chicke', 'inthe!', 'hellomk', 'd1ssdr', 'runaway', 'cfrui54e', 'loveboy',
'fruit1', 'chinni', 'spicy56', 'kukky2', 'toomuch', 'nacc7y', 'june12s', 'oreo09', 'kolly23', 'letsmeet2', 'abc12mj', 'mindtree2', 'hunger45', 'w1o2r3', 'fruit34', 'dntwryc', '12345abcabc', 'body67', 'summer1', 'lalita12', 'australia!', 
'ab89hh', 'werfree', 'fishhy', 'spring', 'buddy15', 'mingle', 'keystr', 'swetha', 'Elsewr2', 'lolluy', 'paris@#', 'gold12', 'davb5@', 'Enmhyh', 'dance3', 'Ehonny2', 'cinema1', 'chinmayi1', '12bgabc', 'github!', 'redmond', 'rain123', 'wx!123',
'12345abc', 'alron@', 'EFgh000', 'Akka!fg', 'enkemi1','helloby7', 'gold12', 'doxxy1', 'hel!@lo', 'Akka!fg', 'c1v2b3', 'pinny1', 'letsmeet2', 'drescc', 'chinni', 'gonny67', '12bgabc', 'dance3', '!missu', 'chicke', 'aolly3', 'Ehonny2', 'buddy15',
'biscuit', 'golddy4', 'w1o2r3', 'fall34', 'ab89hh', 'lolluy', '!loveu', 'dntwryc', 'EFgh000', 'foxxyc', 'cdednt', 'fishhy', 'hunger45', 'loveboy', 'mingle', 'bankloan', 'EFgh!!', 'pillow23', 'carloan', 'qa34ed', 'tracj2', 'eoxxy2', 'enjoy78',
'fruit34', 'good12', 'davb5@', 'shaivi@15', 'carlone', 'fruit1', 'ABC@!sd', 'kolly23', 'iconoic', 'oreo09', 'pressy', 'bronze', 'm1n2b3', 'silver3', 'aug456', 'ruangry1', 'piece2', 'gold34', 'bed456', 'abc123894', 'werfree', 'fruit!3', 'farmy2',
'guntur', 'madboy', 'gutarat', 'pickup', 'vijayawada', 'work12', 'sweety', '12345mnbv', 'cunning', 'babyzz', 'cdemjy', 'broomh', 'pppu78', '7620df', 'abc12mj', 'mouth67', 'spicy56', 'friut2', 'gujarath', 'wtztht', 'mht654', 'kolly1', 'hatty12',
'meaty2', 'malayam', 'tollyu', 'sweaty4', 'runaway', 'cinema1', 'danger45', 'aeonny', '12fonny'])

# %%
TEST CASE 2

# %%
test_case(['CrimsonMachine', 'Starsky', 'Jordan', 'Paycheck', 'Bloodshot', 'Vulture', 'Komoda', 'ToneZone', 'Basketcase', 'Sasquatch', 'Murder', 'TheGoon', 'RonBurgundy', 'Nightcrawler', 'Bloodsoaked',
'Bonecrusher', 'CliffordtheBig', 'Redbull', 'BlazingSaddles', 'Magnum', 'BobtheDestroyer',"6757687","778648","8765348","347%^^g"
"%$hggdh","UYTGtgdsgj","hgfjsyh","hfihsdfhsdfh","6gfh879","76ghdfjk","y657834","64hgjhfg","fhsj87^jdrhg","rhgfjuhdf",
"sjhgdfnbchj","djfnhgiudfhf","shgbfheg","*&^87jhbgcjvhg","qpplrfjirj","gvgh*(&5)","*&*76hjhdfg","hfjksdhfuh","*&^&6hgcjhgd",
"GFUYgdyfg","*^876hcjhdg","&*hjsgdhj","^&djkhf87","fngkjsdh","fhgeurytnbsdhf",'mht654', '12fonny', 'cassty', 'EFghgh', 'hel!@lo',
'carloan', 'EFgh!!', 'malayam',"!!!!!!!!!!!!!!!!","^&%^%&^8*&",'google', 'kolly1', 'ekuva4', 'golddy4', 'hellohek', 'babyzz', 'aeonny', 'aug456', 'cdechu2', 'broomh', 'foxxyc', 'gujarath', '!loveu', 'july24', '1ijk2c', 'country', 'pinny1', 'bronze',
'gonny67', 'summer23', 'farmy2', 'helloby7', 'tfstool1', 'silver3', 'qa34ed', 'itsolu!123', '!missu', 'abc123894', 'sweaty4', 'pickup', 'hatty12', 'pillow23', 'cookee', 'tracj2', 'ruangry1', 'ammulu', 'drescc', '!mkoph',
'c1v2b3', 'sprout', 'gmail2', '1icebc', 'shaivi@15', 'cdemjy', 'doxxy1', 'madboy', 'danger45', 'piece2', 'wtztht', 'carlone', 'enjoy78', 'nastory', 'vrushi!', 'simha12', 'abc123!', 'mouth67', 'good12', 'iconoic', 'aolly3',
'A123ss', 'cdecde', 'biscuit', 'pppu78', 'work12', 'fruit!3', '12345mnbv', 'ABlmnC', 'shaivi', 'E@wrebh', 'spinach', 'gold34', 'february', 'abc66444', 'win123', 'gutarat', 'hotmail1', 'pressy', 'friut2', '!!!!!$wecgh', 'm1n2b3',
'tollyu', 'bankloan', 'denton', 'eoxxy2', 'meaty2', 'bed456', 'ABC@!sd', 'abc123444', 'sweety', 'january', 'fall34', 'Ellenb56gh', 'hapy76', 'cunning', 'cdednt', 'chicke', 'inthe!', 'hellomk', 'd1ssdr', 'runaway', 'cfrui54e', 'loveboy',
'fruit1', 'chinni', 'spicy56', 'kukky2', 'toomuch', 'nacc7y', 'june12s', 'oreo09', 'kolly23', 'letsmeet2', 'abc12mj', 'mindtree2', 'hunger45', 'w1o2r3', 'fruit34', 'dntwryc', '12345abcabc', 'body67', 'summer1', 'lalita12', 'australia!', 
'ab89hh', 'werfree', 'fishhy', 'spring', 'buddy15', 'mingle', 'keystr', 'swetha', 'Elsewr2', 'lolluy', 'paris@#', 'gold12', 'davb5@', 'Enmhyh', 'dance3', 'Ehonny2', 'cinema1', 'chinmayi1', '12bgabc', 'github!', 'redmond', 'rain123', 'wx!123',
'12345abc', 'alron@', 'EFgh000', 'Akka!fg', 'enkemi1','helloby7', 'gold12', 'doxxy1', 'hel!@lo', 'Akka!fg', 'c1v2b3', 'pinny1', 'letsmeet2', 'drescc', 'chinni', 'gonny67', '12bgabc', 'dance3', '!missu', 'chicke', 'aolly3', 'Ehonny2', 'buddy15',
'biscuit', 'golddy4', 'w1o2r3', 'fall34', 'ab89hh', 'lolluy', '!loveu', 'dntwryc', 'EFgh000', 'foxxyc', 'cdednt', 'fishhy', 'hunger45', 'loveboy', 'mingle', 'bankloan', 'EFgh!!', 'pillow23', 'carloan', 'qa34ed', 'tracj2', 'eoxxy2', 'enjoy78',
'fruit34', 'good12', 'davb5@', 'shaivi@15',"%$^$&%&$^&",'carlone', 'fruit1', 'ABC@!sd', 'kolly23', 'iconoic', 'oreo09', 'pressy', 'bronze', 'm1n2b3', 'silver3', 'aug456', 'ruangry1', 'piece2', 'gold34', 'bed456', 'abc123894', 'werfree', 'fruit!3', 'farmy2',
'guntur', 'madboy', 'gutarat', 'pickup', 'vijayawada', 'work12', 'sweety', '12345mnbv', 'cunning', 'babyzz', 'cdemjy', 'broomh', 'pppu78', '7620df', 'abc12mj', 'mouth67', 'spicy56', 'friut2', 'gujarath', 'wtztht', 'mht654', 'kolly1', 'hatty12',
'meaty2', 'malayam', 'tollyu', 'sweaty4', 'runaway', 'cinema1', 'danger45', 'aeonny', '12fonny',"^&%^$$^*&^","GFHGFHGFHJG"
"&^%&GVGH","FGHGFHgfv","TGFHYRYFHGF","%^$^%%^&^","HNJGJHGFHRFTY","YTTTRFYTYTR","4354FGHFHGf","HGHFHFYTFGV675","656^6567",
"#$@%$@!$##$","DFGBDG","JHGJGHHYGFH","^%$^^&879","JHGYUHHFDTGF","%^$^%%^&*^*","JHGHYGHV","TYFGHFYHTFGD","*&^&%&","UYTUJT",
"(*&^%^*(&))","KJHJGTHJFDRD","jdhfjusdfh",'shaivi@15',"%$^$&%&$^&",'carlone', 'fruit1', 'ABC@!sd', 'kolly23', 'iconoic', 'oreo09', 'pressy', 'bronze', 'm1n2b3', 'silver3', 'aug456', 'ruangry1', 'piece2', 'gold34', 'bed456', 'abc123894', 'werfree', 'fruit!3', 'farmy2',
'guntur', 'madboy', 'gutarat', 'pickup', 'vijayawada', 'work12', 'sweety', '12345mnbv', 'cunning', 'babyzz', 'cdemjy', 'broomh', 'pppu78', '7620df', 'abc12mj', 'mouth67', 'spicy56', 'friut2', 'gujarath', 'wtztht', 'mht654', 'kolly1', 'hatty12',
'meaty2', 'malayam', 'tollyu', 'sweaty4', 'runaway', 'cinema1', 'danger45', 'aeonny', '12fonny',"^&%^$$^*&^","GFHGFHGFHJG"
"&^%&GVGH","FGHGFHgfv","TGFHYRYFHGF","%^$^%%^&^","HNJGJHGFHRFTY","YTTTRFYTYTR","4354FGHFHGf","HGHFHFYTFGV675","656^6567",
"#$@%$@!$##$","DFGBDG","JHGJGHHYGFH","^%$^^&879","JHGYUHHFDTGF",'n1p@1!2', '11rc!!', 'nq11nk123', 'dfgbty', 'matyt56', 'npca@245', 'ssndrela12', 'qwamgd1', 'bwecm', 'ab12c5', 'piffnk2', 'a!l!2e23', 'aaana34', 'croyt@@', 'mymm!23', 'hygg!d@23', 'tavvty', 'nnidia!',
'cam22era4', 'myeehuy67', 'heeeo00', 'jarrmu7', 'yggou#85', '!gg!mple', 'prvv12', 'HsG%', 'csadd@', 'Eedp!', 'heso', '1dsac', 'adwb34', '!!!@!$wehkl', 'myunfft@!', 'ABgffdh', 'cde5ff167', 'ghff112', 'helpeeeew12', '3ee452ac', 'c14f!44', '!meeunt', 'evffwen4', 'ODffDw4', 'cae1ml@', 'E12h@%', 'hg3h67', '133765c', 'ab33s44', 'cg3331h!', 'fgrhhsg', 'karnhhaka2', 'camvva2', 'Earrr@1', 'hirriy!', '3ff455c', 'afunty44', 'prasa33d1#', 'frdssog', 'ABc11ss23', 'cdssde2@',           
'aceehiijnrv', '%&afghjs', '123acdgghr', '56ffghh', 'aaekntv', 'adgru', 'CDFFGGHNX', 'CDFFGGHHJV', 'DFFGGJJSY', '5fgghhv', '%^^rv', 'ffgh', 'aadprs', 'aeellnr', '#$4456@aaejnrtuv', 'aaikmrsu', 'eehnntv', 'bddfghhns', 'bddfffggghhhjjssv', 'bbbbdfghhhhjjvv', 'dfghjj', 'bddffggghjjjssv', 'ddfgghjjss', '%%&FGGHHHV^bv', '4455dfgjrs'])



def test_case(a):
  s=[]
  for i in range(0,len(a)): #indexing the str
    t=list(a[i])
    #print(type(p))


    for k in range(0,len(t)):
      #print(t[k])

      for j in range(k+1,len(t)): # from second letter
        #print(t[j])

        if t[k]>t[j]:
          t[k],t[j]=t[j],t[k]
          combine="".join(t)
    s.append(combine)
    p=[]
    m=[]
    for i in range(0,len(a)):
      p.append(i)
      m.append(len(a[i]))
 
import matplotlib.pyplot as plt
plt.xlabel("Length of the string")
plt.ylabel("Order of the string")
plt.title("visualizing all  string based on length")
plt.scatter(p,m)

# %%
TEST CASE 3




test_case(['summer23', 'farmy2', 'helloby7', 'tfstool1', 'silver3', 'qa34ed', 'itsolu!123', '!missu', 'abc123894', 'sweaty4', 'pickup', 'hatty12', 'pillow23', 'cookee', 'tracj2', 'ruangry1', 'ammulu', 'drescc', '!mkoph',
'c1v2b3', 'sprout', 'gmail2', '1icebc', 'shaivi@15', 'cdemjy', 'doxxy1', 'madboy', 'danger45', 'piece2', 'wtztht', 'carlone', 'enjoy78', 'nastory', 'vrushi!', 'simha12', 'abc123!', 'mouth67', 'good12', 'iconoic', 'aolly3',
'A123ss', 'cdecde', 'biscuit', 'pppu78', 'work12', 'fruit!3', '12345mnbv', 'ABlmnC', 'shaivi', 'E@wrebh', 'spinach', 'gold34', 'february', 'abc66444', 'win123', 'gutarat', 'hotmail1', 'pressy', 'friut2', '!!!!!$wecgh', 'm1n2b3',
'tollyu', 'bankloan', 'denton', 'eoxxy2', 'meaty2', 'bed456', 'ABC@!sd', 'abc123444', 'sweety', 'january', 'fall34', 'Ellenb56gh', 'hapy76', 'cunning', 'cdednt', 'chicke', 'inthe!', 'hellomk', 'd1ssdr', 'runaway', 'cfrui54e', 'loveboy',
'fruit1', 'chinni', 'spicy56', 'kukky2', 'toomuch', 'nacc7y', 'june12s', 'oreo09', 'kolly23', 'letsmeet2', 'abc12mj', 'mindtree2', 'hunger45', 'w1o2r3', 'fruit34', 'dntwryc', '12345abcabc', 'body67', 'summer1', 'lalita12', 'australia!', 
'ab89hh', 'werfree', 'fishhy', 'spring', 'buddy15', 'mingle', 'keystr', 'swetha', 'Elsewr2', 'lolluy', 'paris@#', 'gold12', 'davb5@', 'Enmhyh', 'dance3', 'Ehonny2', 'cinema1', 'chinmayi1', '12bgabc', 'github!', 'redmond', 'rain123', 'wx!123',
'12345abc', 'alron@', 'EFgh000', 'Akka!fg', 'enkemi1','helloby7', 'gold12', 'doxxy1', 'hel!@lo', 'Akka!fg', 'c1v2b3', 'pinny1', 'letsmeet2', 'drescc', 'chinni', 'gonny67', '12bgabc', 'dance3', '!missu', 'chicke', 'aolly3', 'Ehonny2', 'buddy15',
'biscuit', 'golddy4', 'w1o2r3', 'fall34', 'ab89hh', 'lolluy', '!loveu', 'dntwryc', 'EFgh000', 'foxxyc', 'cdednt', 'fishhy', 'hunger45', 'loveboy', 'mingle', 'bankloan', 'EFgh!!', 'pillow23', 'carloan', 'qa34ed', 'tracj2', 'eoxxy2', 'enjoy78',
'fruit34', 'good12', 'davb5@', 'shaivi@15',"%$^$&%&$^&",'carlone', 'fruit1', 'ABC@!sd', 'kolly23', 'iconoic', 'oreo09', 'pressy', 'bronze', 'm1n2b3', 'silver3', 'aug456', 'ruangry1', 'piece2', 'gold34', 'bed456', 'abc123894', 'werfree', 'fruit!3', 'farmy2',
'guntur', 'madboy', 'gutarat', 'pickup', 'vijayawada', 'work12', 'sweety', '12345mnbv', 'cunning', 'babyzz', 'cdemjy', 'broomh', 'pppu78', '7620df', 'abc12mj', 'mouth67', 'spicy56', 'friut2', 'gujarath', 'wtztht', 'mht654', 'kolly1', 'hatty12',
'meaty2', 'malayam', 'tollyu', 'sweaty4', 'runaway', 'cinema1', 'danger45', 'aeonny', '12fonny',"^&%^$$^*&^","GFHGFHGFHJG"
"&^%&GVGH","FGHGFHgfv","TGFHYRYFHGF","%^$^%%^&^","HNJGJHGFHRFTY","YTTTRFYTYTR","4354FGHFHGf","HGHFHFYTFGV675","656^6567",
"#$@%$@!$##$","DFGBDG","JHGJGHHYGFH","^%$^^&879","JHGYUHHFDTGF","%^$^%%^&*^*","JHGHYGHV","TYFGHFYHTFGD","*&^&%&","UYTUJT",
"(*&^%^*(&))","KJHJGTHJFDRD","jdhfjusdfh",'shaivi@15',"%$^$&%&$^&",'carlone', 'fruit1', 'ABC@!sd', 'kolly23', 'iconoic', 'oreo09', 'pressy', 'bronze', 'm1n2b3', 'silver3', 'aug456', 'ruangry1', 'piece2', 'gold34', 'bed456', 'abc123894', 'werfree', 'fruit!3', 'farmy2',
'guntur', 'madboy', 'gutarat', 'pickup', 'vijayawada', 'work12', 'sweety', '12345mnbv','building', 'Bhalla.', 'Bhalla', 'deeds.', 'further', "Avantika's", 'attention', 'roughly.', 'lighten', 'combat', 'showing', 'beauty.', 'Avantika', 'becomes', 'friends', 'Mahishmati',
'soldiers.', 'promises', "Avantika's", 'honor,', 'though', "doesn't", 'Devasena', 'important', 'Rebels', 'infiltrates', 'Mahishmati', "Bhalla's", 'erecting', 'golden', 'statue', 'statue', 'catches',
'reveals', 'briefly', 'citizen', 'Baahubali.', 'citizens', 'surrounding', 'Baahubali', 'rebelliously,', "Bhalla's", 'anger.', 'statue', 'positioned,', 'Bhalla', 'demands', 'interrogate', 'guards',
'responsible.', 'disguises', 'himself', 'called', "Bhalla's", 'quarters.', 'escapes', 'successfully', 'Devasena', 'taking', 'kingdom', 'chariot.', 'however', 'stopped', "Bhadra's", 'scouts', 'guards,',
'Kattappa', 'despite', 'beheads', 'Bhadra', 'treated', 'Devasena.', 'Amburis', 'search', 'Rebels.', 'Kattappa', 'charges', 'familiar', 'shouts', '"Baahubali"', 'surrounding', 'tribes', "Kattappa's", 'soldiers',
'cdecde', 'biscuit', 'pppu78',  'buddy15', 'mingle', 'keystr', 'swetha', 'Elsewr2', 'lolluy', 'paris@#', 'gold12', 'davb5@', 'Enmhyh', 'dance3', 'Ehonny2', 'cinema1', 'chinmayi1', '12bgabc', 'github!', 'redmond', 'rain123', 'wx!123',
'12345abc', 'alron@', 'EFgh000', 'Akka!fg', 'enkemi1','helloby7', 'gold12', 'doxxy1', 'hel!@lo', 'Akka!fg', 'c1v2b3', 'pinny1', 'letsmeet2', 'drescc', 'chinni', 'gonny67', '12bgabc', 'dance3', '!missu', 'chicke', 'aolly3', 'Ehonny2', 'buddy15',
'biscuit', 'golddy4', 'w1o2r3', 'fall34', 'ab89hh', 'lolluy', '!loveu', 'dntwryc', 'EFgh000', 'foxxyc', 'cdednt', 'fishhy', 'hunger45', 'loveboy', 'mingle', 'bankloan', 'EFgh!!', 'pillow23', 'carloan', 'qa34ed', 'tracj2', 'eoxxy2', 'enjoy78',
'fruit34', 'good12', 'davb5@', 'shaivi@15',"%$^$&%&$^&",'sweaty4', 'runaway', 'cinema1', 'danger45', 'aeonny', '12fonny',"^&%^$$^*&^","GFHGFHGFHJG"
"&^%&GVGH","FGHGFHgfv","TGFHYRYFHGF","%^$^%%^&^","HNJGJHGFHRFTY","YTTTRFYTYTR","4354FGHFHGf","HGHFHFYTFGV675","656^6567",
"#$@%$@!$##$","DFGBDG","JHGJGHHYGFH",'disappointment', 'however', 'obsessed', 'adventure', 'mountain', 'spends', 'trying', 'performs', 'prayer', 'hoping', 'obedient', 'trying,',
'involving', 'pouring', 'buckets', 'Lingam', 'pedestal.', 'dislodges', 'Lingam', 'showing', 'somehow', 'superhuman', 'strength.', 'carries', 'bottom', 'waterfall,',
'realizes', 'feminine', 'washed', 'further', 'motivated', 'venture', 'mountain', 'belongs', 'successfully', 'scales', 'mountain', 'Avantika', 'chased', 'soldiers',
'kingdom', 'called'])

def test_case(a):
  s=[]
  for i in range(0,len(a)): #indexing the str
    t=list(a[i])
    #print(type(p))


    for k in range(0,len(t)):
      #print(t[k])

      for j in range(k+1,len(t)): # from second letter
        #print(t[j])

        if t[k]>t[j]:
          t[k],t[j]=t[j],t[k]
          combine="".join(t)
    s.append(combine)
    p=[]
    m=[]
    for i in range(0,len(a)):
      p.append(i)
      m.append(len(a[i]))
 
import matplotlib.pyplot as plt
plt.xlabel("Length of the string")
plt.ylabel("Order of the string")
plt.title("visualizing all  string based on length")
plt.scatter(p,m)

# %%
TEST CASE 4





test_case(["^&&**)(*)","HJGHFT","(*&*^&%)","HGNUYGHJGJH","YTR%^$^%R&^T","HJNGVHFHF","HGFHBFGHCGHFYTF","&^%&^*&&()","GFVBHFHGB",
"&*^*&^&%vgvfg","UTYHTFGHFGHTF","IUYTGHVHV",'Outside', 'enormous', 'waterfall,', 'Sivagami', 'carrying', 'tired,', 'injured,', 
'exhausted', 'realizes', 'soldiers', 'following', 'strategically', 'places', 'swords', 'before', 'fleeing.', 'accidentally', 'caught',
'current', 'unable', 'shore.', 'Sivagami', 'Shiva,', "evil's", 'destruction', 'mistakes,', 'Mahendra', 'Baahubali', 'light.', 'drowns', 
'before', 'holding', 'Mahendra', 'surface', 'villagers', 'villagers', 'Amburi', 'tribe,', 'reside', 'worship', 'Shiva.', 'leader', 'village,',
'discovers', 'drowned', 'evaded', 'soldiers', 'through', 'secret', 'escape', 'Sivagami', 'pointed', 'towards', 'mountain', 'before', "Sanga's", 
'husband', 'realizes', 'refuses', 'worrying', 'safety.', 'decides', 'Shivudu,', 'Shivu.', 'Shivudu', 'young,', 'acrobatic,', 'adventurous,', 'hearted',
"Sanga's", 'disappointment', 'however', 'obsessed', 'adventure', 'mountain', 'spends', 'trying', 'performs', 'prayer', 'hoping', 'obedient', 'trying,',
'involving', 'pouring', 'buckets', 'Lingam', 'pedestal.', 'dislodges', 'Lingam', 'showing', 'somehow', 'superhuman', 'strength.', 'carries', 'bottom', 'waterfall,',
'realizes', 'feminine', 'washed', 'further', 'motivated', 'venture', 'mountain', 'belongs', 'successfully', 'scales', 'mountain', 'Avantika', 'chased', 'soldiers',
'kingdom', 'called', 'Mahishmati.', 'Avantika', 'damsel', 'slaughter', 'soldiers.', 'Avantika', 'reports', "tribe's", 'leader,', 'rebels', 'hailing', 'fallen', 'kingdom',
'Kuntala.', 'Varma,', 'declares', 'liberate', 'Mahishmati', 'emperor', 'Bhallaladeva,', 'Bhalla.', 'Bhalla', 'holding', "Varma's", 'sister', 'Devasena', 'hostage,', 'torturing',
'basis.', 'Avantika', 'Kattappa,', 'rightous', 'warrior', 'residing', 'Mahishmati', 'cause.', 'confirms', 'Kattappa', 'motivation', 'royals', 'Mahishmati', 'ancestors', 
'Kattappa', 'oversees', 'weapon', 'manufacturing', 'Mahishmati,', "Bhalla's", 'achieved', 'through', 'labor.', 'Kattappa', 'visited', 'weapon', 'trader', 'befriends', 'sharing',
'duties', 'Kattappa', 'skilled', 'strong', 'warrior', 'lineage', 'despite', 'general', 'commander', "Bhalla's", 'birthday', 'upcoming,', 'perfect', 'opportunity', 'rescue',
'Devasena.', 'granted', 'Avantika,', 'painting', 'resting', 'earlier.', 'Though', 'accused', 'neglecting', 'beauty,', 'assures', 'mission', 'anything.', 'kingdom', 'Mahishmati',
'unjust', 'treatment', 'towards', 'citizens', 'controlling', 'obsessed', 'Bhallaladeva.', 'living', 'Bhalla', 'father', 'Bijjaladeva', 'Prince', 'Bhadrudu', '(alias', 'Bhadra).',
"Bhalla's", 'captured', 'forest', 'strenght.', 'defeats', 'notices', 'Kattappa', 'killing', 'distracted.', 'Bhalla', 'Kattappa', 'Kattappa', 'badly,', 'wonders', 'Kattappa',
'remains', 'loyal.', 'decides', 'Kattappa', 'release', 'Devasena.', 'Bhalla', 'allows', 'Kattappa', 'refuses.', 'Kattappa', 'visits', 'Devasena', 'Devasena', 'refuses', 'frustrated,',
'spending', 'building', 'Bhalla.', 'Bhalla', 'deeds.', 'further', "Avantika's", 'attention', 'roughly.', 'lighten', 'combat', 'showing', 'beauty.', 'Avantika', 'becomes', 'friends', 'Mahishmati',
'soldiers.', 'promises', "Avantika's", 'honor,', 'though', "doesn't", 'Devasena', 'important', 'Rebels', 'infiltrates', 'Mahishmati', "Bhalla's", 'erecting', 'golden', 'statue', 'statue', 'catches',
'reveals', 'briefly', 'citizen', 'Baahubali.', 'citizens', 'surrounding', 'Baahubali', 'rebelliously,', "Bhalla's", 'anger.', 'statue', 'positioned,', 'Bhalla', 'demands', 'interrogate', 'guards',
'responsible.', 'disguises', 'himself', 'called', "Bhalla's", 'quarters.', 'escapes', 'successfully', 'Devasena', 'taking', 'kingdom', 'chariot.', 'however', 'stopped', "Bhadra's", 'scouts', 'guards,',
'Kattappa', 'despite', 'beheads', 'Bhadra', 'treated', 'Devasena.', 'Amburis', 'search', 'Rebels.', 'Kattappa', 'charges', 'familiar', 'shouts', '"Baahubali"', 'surrounding', 'tribes', "Kattappa's", 'soldiers',
'cdecde', 'biscuit', 'pppu78',  'buddy15', 'mingle', 'keystr', 'swetha', 'Elsewr2', 'lolluy', 'paris@#', 'gold12', 'davb5@', 'Enmhyh', 'dance3', 'Ehonny2', 'cinema1', 'chinmayi1', '12bgabc', 'github!', 'redmond', 'rain123', 'wx!123',
'12345abc', 'alron@', 'EFgh000', 'Akka!fg', 'enkemi1','helloby7', 'gold12', 'doxxy1', 'hel!@lo', 'Akka!fg', 'c1v2b3', 'pinny1', 'letsmeet2', 'drescc', 'chinni', 'gonny67', '12bgabc', 'dance3', '!missu', 'chicke', 'aolly3', 'Ehonny2', 'buddy15',
'biscuit', 'golddy4', 'w1o2r3', 'fall34', 'ab89hh', 'lolluy', '!loveu', 'dntwryc', 'EFgh000', 'foxxyc', 'cdednt', 'fishhy', 'hunger45', 'loveboy', 'mingle', 'bankloan', 'EFgh!!', 'pillow23', 'carloan', 'qa34ed', 'tracj2', 'eoxxy2', 'enjoy78',
'fruit34', 'good12', 'davb5@', 'shaivi@15',"%$^$&%&$^&",'carlone', 'fruit1', 'ABC@!sd', 'kolly23', 'iconoic', 'oreo09', 'pressy', 'bronze', 'm1n2b3', 'silver3', 'aug456', 'ruangry1', 'piece2', 'gold34', 'bed456', 'abc123894', 'werfree', 'fruit!3', 'farmy2',
'guntur', 'madboy', 'gutarat', 'pickup', 'vijayawada', 'work12', 'sweety', '12345mnbv', 'cunning', 'babyzz', 'cdemjy', 'broomh', 'pppu78', '7620df', 'abc12mj', 'mouth67', 'spicy56', 'friut2', 'gujarath', 'wtztht', 'mht654', 'kolly1', 'hatty12',
'meaty2', 'malayam', 'tollyu', 'sweaty4', 'runaway', 'cinema1', 'danger45', 'aeonny', '12fonny',"^&%^$$^*&^","GFHGFHGFHJG"
"&^%&GVGH","FGHGFHgfv","TGFHYRYFHGF","%^$^%%^&^","HNJGJHGFHRFTY","YTTTRFYTYTR","4354FGHFHGf","HGHFHFYTFGV675","656^6567",
"#$@%$@!$##$","DFGBDG","JHGJGHHYGFH"])


def test_case(a):
  s=[]
  for i in range(0,len(a)): #indexing the str
    t=list(a[i])
    #print(type(p))


    for k in range(0,len(t)):
      #print(t[k])

      for j in range(k+1,len(t)): # from second letter
        #print(t[j])

        if t[k]>t[j]:
          t[k],t[j]=t[j],t[k]
          combine="".join(t)
    s.append(combine)
    p=[]
    m=[]
    for i in range(0,len(a)):
      p.append(i)
      m.append(len(a[i]))
 
import matplotlib.pyplot as plt
plt.xlabel("Length of the string")
plt.ylabel("Order of the string")
plt.title("visualizing all  string based on length")
plt.scatter(p,m)

# %%
TEST CASE 5 





test_case([ 'beheads', 'belongs', 'birthday', 'biscuit', 'biscuit', 'bottom', 'briefly', 'bronze', 'broomh', 'buckets', 
'buddy15', 'buddy15', 'building', 'c1v2b3', 'called', 'called', 'captured', 'carloan', 'carlone', 'carries', 'carrying',
'catches', 'caught', 'cause.', 'cdecde', 'cdednt', 'cdemjy', 'charges', 'chariot.', 'chased', 'chicke', 'chinmayi1',
'chinni', 'cinema1', 'cinema1', 'citizen', 'citizens', 'citizens', 'combat', 'commander', 'confirms', 'controlling',
'cunning', 'current', 'damsel', 'dance3', 'dance3', 'danger45', 'davb5@', 'davb5@', 'decides', 'decides', 'declares',
'deeds.', 'defeats', 'demands', 'despite', 'despite', 'destruction', 'disappointment', 'discovers', 'disguises',
'dislodges', 'distracted.', 'dntwryc', "doesn't", 'doxxy1', 'drescc', 'drowned', 'drowns', 'duties', 'earlier.',
'emperor', 'enjoy78', 'enkemi1', 'enormous', 'eoxxy2', 'erecting', 'escape', 'escapes', 'evaded', "evil's", 'exhausted',
'fall34', 'fallen', 'familiar', 'farmy2', 'father', 'feminine', 'fishhy', 'fleeing.', 'following', 'forest', 'foxxyc',
'friends', 'friut2', 'fruit!3', 'fruit1', 'fruit34', 'frustrated,', 'further', 'further', 'general', 'github!',
'gold12', 'gold12', 'gold34', 'golddy4', 'golden', 'gonny67', 'good12', 'granted', 'guards', 'guards,', 'gujarath',
'guntur', 'gutarat', 'hailing', 'hatty12', 'hearted', 'hel!@lo', 'helloby7', 'himself', 'holding', 'holding', 'honor,',
'hoping', 'hostage,', 'however', 'however', 'hunger45', 'husband', 'iconoic', 'important', 'infiltrates', 'injured,',
'interrogate', 'involving', 'keystr', 'killing', 'kingdom', 'kingdom', 'kingdom', 'kingdom', 'kolly1', 'kolly23',
'labor.', 'leader', 'leader,', 'letsmeet2', 'liberate', 'light.', 'lighten', 'lineage', 'living', 'lolluy', 'lolluy',
'loveboy', 'loyal.', 'm1n2b3', 'madboy', 'malayam', 'manufacturing', 'meaty2', 'mht654', 'mingle', 'mingle', 'mission',
'mistakes,', 'motivated', 'motivation', 'mountain', 'mountain', 'mountain', 'mountain', 'mouth67', 'neglecting',
'notices', 'obedient', 'obsessed', 'obsessed', 'opportunity', 'oreo09', 'oversees', 'painting', 'paris@#',
'pedestal.', 'perfect', 'performs', 'pickup', 'piece2', 'pillow23', 'pinny1', 'places', 'pointed', 'positioned,',
'pouring', 'pppu78', 'pppu78', 'prayer', 'pressy', 'promises', 'qa34ed', 'quarters.', 'rain123', 'realizes', 
'realizes', 'realizes', 'rebelliously,', 'rebels', 'redmond', 'refuses', 'refuses', 'refuses.', 'release', 'remains',
'reports', 'rescue', 'reside', 'residing', 'responsible.', 'resting', 'reveals', 'rightous', 'roughly.', 'royals',
'ruangry1', 'runaway', 'safety.', 'scales', 'scouts', 'search', 'secret', 'shaivi@15', 'sharing', 'shore.', 'shouts',
'showing', 'showing', 'silver3', 'sister', 'skilled', 'slaughter', 'soldiers', 'soldiers', 'soldiers', 'soldiers',
'soldiers.', 'soldiers.', 'somehow', 'spending', 'spends', 'spicy56', 'statue', 'statue', 'statue', 'stopped',
'strategically', 'strenght.', 'strength.', 'strong', 'successfully', 'successfully', 'superhuman', 'surface',
'surrounding', 'surrounding','mighty', '(Prabhas),', 'aspires', 'waterfall', 'parbat)', "what's", 'there.', 'curiosity',
'mother', 'dangerous.', 'failed', 'attempts', 'finally', 'Looking', '(Tamannaah', 'Avantika)', 'mysterious', 'discovers',
'unlike', 'dreams,', 'rebellious', 'warrior', 'fighting', 'against', 'Bhallala', 'Daggubati),', 'captured', 'Devasena',
'(Anushka', 'Shetty)', 'years.', 'indulges', 'guerrilla', 'warfare', 'against', 'rescue', 'queen.', 'initially', 'doubts',
"shiva's", 'intentions,', 'seeing', 'realises', 'innocent.', 'pledges', 'mission.', 'sneaks', 'Bhallala', "deva's", 'Mahismathi',
'kingdom', 'rescue', 'Devasena', 'almost', 'manages', 'caught.', "king़'s", 'kattapa', 'attacks', 'strength,', 'realises', 'Amarendra',
"Bahubaali's", '(Prabhas', 'deserving', 'Mahismathi', 'kingdom.', 'flashback', 'Amarendra', 'Baahubali', 'Bhallala', 'cousin', 'brother.',
'Though', "Bhallala's", 'father', 'Bajjala', '(Nasser)', 'brother,', "Shiva's", 'grandfather', 'crowned', 'worthy.', 'Bajjala', 'resents',
'decision.', 'brother', 'Bajjala', 'wishes', 'Bhallala', 'emperor', "king's", 'before', "(Shiva's", 'father', 'Amarendra', 'Baahubali)', 'another',
'kingdom.', "Bajjala's", 'Sivagami', '(Ramya)', 'feisty,', 'impartial.', 'raises', 'children', 'Bhallala', 'Baahubali', 'proclaims', 'whoever', 'proves',
'deserving', 'crowned', 'Bajjala', "Bhallala's", 'tactics', 'witnessing', 'battle', 'against', 'Kalkeyas', '(tribal', 'rivals)', 'Sivagami', 'announces',
'Baahubali', 'people.', 'sharing', 'Kattapa', 'interrupted', 'asked,', 'father', 'strong', '(Baahubali)', 'killed', 'Kattapa,', 'betrayed', 'life."',
"GJHGFHF","^&%&*&*","HGHJGJHGJY","I&Y^UYGFYTRT","TUHGVHNFYHG","&^*%$*&()","UYGTHFG","(*&^%$)","(*&^%)","!@#$%^","KUJHYGJH",
"%$%^&*&HJG","6786786ghfh","&^GHFHF","JHGJHGHGt76t","JYHGHJGF","(*&^%$)","IUYTHGFD","IKUJHYFGT",")(*&^%$#@)",
"GFDXFFVCGF","UYTHGFHFt","T^%^&%","#$%#$%$fghf","VCGFTGHFCVGH","CVHGFYHGFG","%^^%fghf675","YTRFTHGFHTGF","IKUYTGFD",
"$5f5ytr45","?FGBHFVhgf","HVGHFHTG","*I&^U%$RFDGH","TFGBCGF","UYTHGVHYF","^%&**^%&5","GVCHGFGHV","FTFTFHGFYUTg",
"HGFYTFGVHF","^&%RTRFY&^TR","NBBJHYTGHY","HGBHYGHBg","*&^%&*^gbhjg","NHVHGFHGVGv","VNBGFHVFH",
"GVNBFHVGHFV65","67576VCFGHF54","HGHJGJHGJY","I&Y^UYGFYTRT","TUHGVHNFYHG","&^*%$*&()","UYGTHFG","(*&^%$)","(*&^%)","!@#$%^","KUJHYGJH",
"%$%^&*&HJG","6786786ghfh","&^GHFHF","JHGJHGHGt76t","JYHGHJGF","(*&^%$)","IUYTHGFD","IKUJHYFGT",")(*&^%$#@)",
"GFDXFFVCGF","UYTHGFHFt","T^%^&%","#$%#$%$fghf","VCGFTGHFCVGH","CVHGFYHGFG","%^^%fghf675","YTRFTHGFHTGF","IKUYTGFD",
"$5f5ytr45","?FGBHFVhgf"])


def test_case(a):
  s=[]
  for i in range(0,len(a)): #indexing the str
    t=list(a[i])
    #print(type(p))


    for k in range(0,len(t)):
      #print(t[k])

      for j in range(k+1,len(t)): # from second letter
        #print(t[j])

        if t[k]>t[j]:
          t[k],t[j]=t[j],t[k]
          combine="".join(t)
    s.append(combine)
    p=[]
    m=[]
    for i in range(0,len(a)):
      p.append(i)
      m.append(len(a[i]))
 
import matplotlib.pyplot as plt
plt.xlabel("Length of the string")
plt.ylabel("Order of the string")
plt.title("visualizing all  string based on length")
plt.scatter(p,m)
